# %%
from langchain_ollama import ChatOllama
chat = ChatOllama(model="deepseek-r1:1.5b");
chat.invoke("How are you?");

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b");
llm.invoke("What is capital of Korea?");

# %%
# %pip install -q langchain-openai
# Out:
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o-mini");
llm.invoke("What is capital of Korea?");
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[16], line 2
#       1 from langchain_openai import ChatOpenAI
# ----> 2 llm = ChatOpenAI(model="gpt-4o-mini");
#       3 llm.invoke("What is capital of Korea?");
#
# File ~/.pyenv/versions/3.11.0/envs/langchain-basics/lib/python3.11/site-packages/langchain_core/load/serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/.pyenv/versions/3.11.0/envs/langchain-basics/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:914, in BaseChatOpenAI.validate_environment(self)
#     904         self.http_async_client = httpx.AsyncClient(
#     905             proxy=self.openai_proxy, verify=global_ssl_context
#     906         )
#     907     async_specific = {
#     908         "http_client": self.http_async_client
#     909         or _get_default_async_httpx_client(
#    (...)    912         "api_key": async_api_key_value,
#     913     }
# --> 914     self.root_async_client = openai.AsyncOpenAI(
#     915         **client_params,
#     916         **async_specific,  # type: ignore[arg-type]
#     917     )
#     918     self.async_client = self.root_async_client.chat.completions
#     919 return self
#
# File ~/.pyenv/versions/3.11.0/envs/langchain-basics/lib/python3.11/site-packages/openai/_client.py:488, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     486     api_key = os.environ.get("OPENAI_API_KEY")
#     487 if api_key is None:
# --> 488     raise OpenAIError(
#     489         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     490     )
#     491 if callable(api_key):
#     492     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o-mini");
llm.invoke("What is capital of Korea?");
# Out:
# OpenAI API 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# Ollama 모델로 전환합니다...
# Ollama Response: The capital of South Korea is Seoul.

# %%
from langchain_openai import AzureChatOpenAI
llm = AzureChatOpenAI(model="gpt-4o-mini");
llm.invoke("What is capital of Korea?");
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[36], line 3
#       1 from langchain_openai import AzureChatOpenAI
#       2 llm = AzureChatOpenAI(model="gpt-4o-mini");
# ----> 3 llm.invoke("What is capital of Korea?");
#
# File ~/.pyenv/versions/3.11.0/envs/langchain-basics/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:382, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     368 @override
#     369 def invoke(
#     370     self,
#    (...)    375     **kwargs: Any,
#     376 ) -> AIMessage:
#     377     config = ensure_config(config)
#     378     return cast(
#     379         "AIMessage",
#     380         cast(
#     381             "ChatGeneration",
# --> 382             self.generate_prompt(
#     383                 [self._convert_input(input)],
#     384                 stop=stop,
#     385                 callbacks=config.get("callbacks"),
#     386                 tags=config.get("tags"),
#     387                 metadata=config.get("metadata"),
#     388                 run_name=config.get("run_name"),
#     389                 run_id=config.pop("run_id", None),
#     390                 **kwargs,
#     391             ).generations[0][0],
#     392         ).message,
#     393     )
#
# File ~/.pyenv/versions/3.11.0/envs/langchain-basics/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:1101, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1092 @override
#    1093 def generate_prompt(
#    1094     self,
#    (...)   1098     **kwargs: Any,
#    1099 ) -> LLMResult:
#    1100     prompt_messages = [p.to_messages() for p in prompts]
# -> 1101     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/.pyenv/versions/3.11.0/envs/langchain-basics/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:911, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     908 for i, m in enumerate(input_messages):
#     909     try:
#     910         results.append(
# --> 911             self._generate_with_cache(
#     912                 m,
#     913                 stop=stop,
#     914                 run_manager=run_managers[i] if run_managers else None,
#     915                 **kwargs,
#     916             )
#     917         )
#     918     except BaseException as e:
#     919         if run_managers:
#
# File ~/.pyenv/versions/3.11.0/envs/langchain-basics/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:1205, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1203     result = generate_from_stream(iter(chunks))
#    1204 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1205     result = self._generate(
#    1206         messages, stop=stop, run_manager=run_manager, **kwargs
#    1207     )
#    1208 else:
#    1209     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/.pyenv/versions/3.11.0/envs/langchain-basics/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:1299, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1297     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1298         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1299     raise e
#    1300 if (
#    1301     self.include_response_headers
#    1302     and raw_response is not None
#    1303     and hasattr(raw_response, "headers")
#    1304 ):
#    1305     generation_info = {"headers": dict(raw_response.headers)}
#
# File ~/.pyenv/versions/3.11.0/envs/langchain-basics/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:1294, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1287         return _construct_lc_result_from_responses_api(
#    1288             response,
#    1289             schema=original_schema_obj,
#    1290             metadata=generation_info,
#    1291             output_version=self.output_version,
#    1292         )
#    1293     else:
# -> 1294         raw_response = self.client.with_raw_response.create(**payload)
#    1295         response = raw_response.parse()
#    1296 except Exception as e:
#
# File ~/.pyenv/versions/3.11.0/envs/langchain-basics/lib/python3.11/site-packages/openai/_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     360 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/.pyenv/versions/3.11.0/envs/langchain-basics/lib/python3.11/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.0/envs/langchain-basics/lib/python3.11/site-packages/openai/resources/chat/completions/completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File ~/.pyenv/versions/3.11.0/envs/langchain-basics/lib/python3.11/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.pyenv/versions/3.11.0/envs/langchain-basics/lib/python3.11/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'code': '401', 'message': 'Access denied due to invalid subscription key or wrong API endpoint. Make sure to provide a valid key for an active subscription and use a correct regional API endpoint for your resource.'}}

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b");
llm.invoke("What is capital of Korea?");
